# %%
## 고딩
import json
import pandas as pd
import numpy as np

# JSON 파일을 읽어서 파싱
with open('상담기록_데이터_고등학교_train.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# 데이터 추출
rows = []
for key, value in data.items():
    student_idx = value['meta']['student_idx']
    row = {'student_idx': student_idx, 'conversation_자아이해': '', 'conversation_교육기회탐색': '', 'conversation_직업정보탐색': ''}
    
    for conv in value['conversation']:
        if conv['conv_category'] == '자아이해':
            row['conversation_자아이해'] += ' ' + ' '.join([utterance['utterance'] for utterance in conv['utterances']])
        elif conv['conv_category'] == '직업이해':
            row['conversation_직업이해'] = ' '.join([utterance['utterance'] for utterance in conv['utterances']])
        elif conv['conv_category'] == '교육기회탐색':
            row['conversation_교육기회탐색'] += ' ' + ' '.join([utterance['utterance'] for utterance in conv['utterances']])
        elif conv['conv_category'] == '직업정보탐색':
            row['conversation_직업정보탐색'] += ' ' + ' '.join([utterance['utterance'] for utterance in conv['utterances']])
        
    rows.append(row)

# DataFrame 생성
df = pd.DataFrame(rows)

# 짝수행의 내용 뒤에 홀수행의 내용 이어붙이기
combined_rows = []
for i in range(0, len(df), 2):
    combined_row = df.iloc[i].copy()
    if i + 1 < len(df) and df.iloc[i]['student_idx'] == df.iloc[i + 1]['student_idx']:
        combined_row['conversation_자아이해'] += ' ' + df.iloc[i + 1]['conversation_자아이해']
        combined_row['conversation_교육기회탐색'] += ' ' + df.iloc[i + 1]['conversation_교육기회탐색']
        combined_row['conversation_직업정보탐색'] += ' ' + df.iloc[i + 1]['conversation_직업정보탐색']
    combined_rows.append(combined_row)

# 새로운 DataFrame 생성
data_high = pd.DataFrame(combined_rows)

# NaN 처리
data_high.replace(' ', np.nan, inplace=True)
data_high.reset_index(drop=True, inplace=True)
display(data_high.head())
# Out:
#   student_idx                                  conversation_자아이해  \
# 0      S-0026   같이 간 친구들은 모두 친한 친구들인가요? 네 중학교 때부터 친한 친구들이요 학생...
# 1      S-0028   학생은 음악, 게임, 산책을 좋아한다고 했는데 산책은 주로 집 근처에서 하나요? ...
# 2      S-0029   학생은 사회성도 좋으면서 공간지각력이 높고, 학업성취도 높은 편일 거 같아요. 혹...
# 3      S-0030   네~ 자기소개 부탁해요. 잘하는 것. 좋아하는 것. 관심 있는 것 등등 저는 스마...
# 4      S-0031                                                NaN
#
#                                  conversation_교육기회탐색  \
# 0   학생은 3학년인데 그럼 혹시 수능 준비를 하고 있나요? 아니요 일단은 취업을 하기...
# 1   학생은 증권사, 회계사무인 쪽 일을 하고 싶다고 했는데 맞나요? 네 맞습니다 그 ...
# 2   학생은 3학년이라 고등학교 진학에 신경을 쓰고 있을 거 같아요. 생각해둔 학교가 ...
# 3    저, 아직은 방송을 시작도 안 해봤고, 방송하려고 하면 좀 떨린다고 해야 하나....
# 4   네. 교사에 대해서 알고 싶은 것이 뭔가요? 교사가 되려면 내신을 몇 등급 정도 ...
#
#                                  conversation_직업정보탐색  \
# 0    전체적으로 봤을 때 금융회사나 증권사 애널리스트 등이 모두 추천할만한 직업입니다...
# 1    검사 결과가 타당한 거 같아요? 요즘 유튜브 1인 크리에이터 많잖아요. 일하면서...
# 2   학생이 하고 싶은 일로 디자인 법조계 일을 꼽았는데 어떤 점이 매력이 있었을까요?...
# 3   게임 분야를 생각하고 있군요. 유튜브로 어떤 분야든 고객과 소통하려면 재미있고 새...
# 4    자연 계열 교사의 핵심 능력이 뭔가요? 언어능력, 수리 논리력, 자기성찰 능력입...
#
#                                    conversation_직업이해
# 0                                                NaN
# 1                                                NaN
# 2  그러면 법조계 일 중에는 어느 분야가 관심이 가나요? 검사요! 네 [이모티콘] 이유...
# 3  이 프로젝트를 참여한 이유는 제가 2가지 직업을 해놨는데 둘 다 정말 할 수 있을까...
# 4  **고등학교 학년이고, 교사를 지망하고 있습니다. 교사를 지망하는군요. 교사가 되고...

# %%
print(data_high.isnull().sum())
print(data_high.shape)
# Out:
# student_idx              0
# conversation_자아이해       85
# conversation_교육기회탐색     78
# conversation_직업정보탐색    193
# conversation_직업이해      638
# dtype: int64
# (1458, 5)

# %%
temp_high = data_high.dropna(axis = 0)
print(temp_high.isnull().sum())
print(temp_high.shape)
# Out:
# student_idx            0
# conversation_자아이해      0
# conversation_교육기회탐색    0
# conversation_직업정보탐색    0
# conversation_직업이해      0
# dtype: int64
# (729, 5)

# %% [markdown]
# ## 중딩

# %%
## 중딩
import json
import pandas as pd
import numpy as np

# JSON 파일을 읽어서 파싱
with open('상담기록_데이터_중학교_train.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# 데이터 추출
rows = []
for key, value in data.items():
    student_idx = value['meta']['student_idx']
    row = {'student_idx': student_idx, 'conversation_자아이해': '', 'conversation_교육기회탐색': '', 'conversation_직업정보탐색': ''}
    
    for conv in value['conversation']:
        if conv['conv_category'] == '자아이해':
            row['conversation_자아이해'] += ' ' + ' '.join([utterance['utterance'] for utterance in conv['utterances']])
        elif conv['conv_category'] == '직업이해':
            row['conversation_직업이해'] = ' '.join([utterance['utterance'] for utterance in conv['utterances']])
        elif conv['conv_category'] == '교육기회탐색':
            row['conversation_교육기회탐색'] += ' ' + ' '.join([utterance['utterance'] for utterance in conv['utterances']])
        elif conv['conv_category'] == '직업정보탐색':
            row['conversation_직업정보탐색'] += ' ' + ' '.join([utterance['utterance'] for utterance in conv['utterances']])
        
    rows.append(row)

# DataFrame 생성
df = pd.DataFrame(rows)

# 짝수행의 내용 뒤에 홀수행의 내용 이어붙이기
combined_rows = []
for i in range(0, len(df), 2):
    combined_row = df.iloc[i].copy()
    if i + 1 < len(df) and df.iloc[i]['student_idx'] == df.iloc[i + 1]['student_idx']:
        combined_row['conversation_자아이해'] += ' ' + df.iloc[i + 1]['conversation_자아이해']
        combined_row['conversation_교육기회탐색'] += ' ' + df.iloc[i + 1]['conversation_교육기회탐색']
        combined_row['conversation_직업정보탐색'] += ' ' + df.iloc[i + 1]['conversation_직업정보탐색']
    combined_rows.append(combined_row)

# 새로운 DataFrame 생성
data_middle = pd.DataFrame(combined_rows)

# NaN 처리
data_middle.replace(' ', np.nan, inplace=True)
data_middle.reset_index(drop=True, inplace=True)
display(data_middle.head())
# Out:
#   student_idx                                  conversation_자아이해  \
# 0      S-0022   네~ 혹시 학생은 MBTI를 해봤나요? 네 뭐예요? Entp요 네~ 선생님은 학생...
# 1      S-0024   학생은 친구가 많나요? 그냥 적당히 있는 거 같아요 가장 친하다고 느끼는 친구는 ...
# 2      S-0027   학생은 강아지를 좋아한다고 했는데 지금 강아지를 키우고 있나요? 학생은 어떤 운동...
# 3      S-0032   그렇군요. 학생 소개 좀 해주세요~ 네. 저는 중학생이고요 고고학자가 꿈이에요. ...
# 4      S-0034   요즘 주로 하는 무얼 하며 보내는 시간이 제일 많나요? 노래를 듣거나 피아노, 플...
#
#                                  conversation_교육기회탐색  \
# 0   그러면 지금 3학년인데 고등학교 진학해야 하잖아요. 생각해둔 학교가 있나요? 네 ...
# 1   학생은 요리사를 진로로 생각해본 적은 있어요? 식품연구원 생각했었어요 아주 잘 맞...
# 2   운동선수를 하고 싶다고 했는데 태권도 선수인가요? 태권도 선수요 그럼 지금 쉬고 ...
# 3   이제 전공을 알아봅시다. 위쪽에 관련학과에서 사학과를 클릭하세요. 클릭했습니다 영...
# 4   혹시 진로 검사나 심리검사를 받아본 적이 있나요? 학교에서 다양한 검사를 해봤을 ...
#
#                                  conversation_직업정보탐색  \
# 0   학생은 알고 있는 직업으로 경호원과 화이트해커를 적어주었는데 그 직업들에 관심도 ...
# 1    혹시 커리어넷에서 검사는 다 해보았을까요? 결과를 알려줄 수 있을까요? 네 이거...
# 2                                                NaN
# 3   커리어넷 알고 있나요? 몰랐어요 앞으로 더 찾아볼게요! 몰랐어요 지금 컴퓨터나 태...
# 4   워크넷에 들어가 보면 다양한 직업 찾기와 직업인 인터뷰를 통해 간접 체험과 직업에...
#
#                                    conversation_직업이해
# 0  학생 세대의 기대수명이 140세라는 얘기를 들어본 적이 있나요? 수명이 많이 늘어나...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
print(data_middle.isnull().sum())
print(data_middle.shape)
# Out:
# student_idx               0
# conversation_자아이해       138
# conversation_교육기회탐색     264
# conversation_직업정보탐색     373
# conversation_직업이해      1115
# dtype: int64
# (2554, 5)

# %%
temp_middle = data_middle.dropna(axis = 0)
print(temp_middle.isnull().sum())
print(temp_middle.shape)
# Out:
# student_idx            0
# conversation_자아이해      0
# conversation_교육기회탐색    0
# conversation_직업정보탐색    0
# conversation_직업이해      0
# dtype: int64
# (1221, 5)

# %% [markdown]
# ## 초딩

# %%
## 초딩
import json
import pandas as pd
import numpy as np

# JSON 파일을 읽어서 파싱
with open('상담기록_데이터_초등학교_train.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# 데이터 추출
rows = []
for key, value in data.items():
    student_idx = value['meta']['student_idx']
    row = {'student_idx': student_idx, 'conversation_자아이해': '', 'conversation_교육기회탐색': '', 'conversation_직업정보탐색': ''}
    
    for conv in value['conversation']:
        if conv['conv_category'] == '자아이해':
            row['conversation_자아이해'] += ' ' + ' '.join([utterance['utterance'] for utterance in conv['utterances']])
        elif conv['conv_category'] == '직업이해':
            row['conversation_직업이해'] = ' '.join([utterance['utterance'] for utterance in conv['utterances']])
        elif conv['conv_category'] == '교육기회탐색':
            row['conversation_교육기회탐색'] += ' ' + ' '.join([utterance['utterance'] for utterance in conv['utterances']])
        elif conv['conv_category'] == '직업정보탐색':
            row['conversation_직업정보탐색'] += ' ' + ' '.join([utterance['utterance'] for utterance in conv['utterances']])
        
    rows.append(row)

# DataFrame 생성
df = pd.DataFrame(rows)

# 짝수행의 내용 뒤에 홀수행의 내용 이어붙이기
combined_rows = []
for i in range(0, len(df), 2):
    combined_row = df.iloc[i].copy()
    if i + 1 < len(df) and df.iloc[i]['student_idx'] == df.iloc[i + 1]['student_idx']:
        combined_row['conversation_자아이해'] += ' ' + df.iloc[i + 1]['conversation_자아이해']
        combined_row['conversation_교육기회탐색'] += ' ' + df.iloc[i + 1]['conversation_교육기회탐색']
        combined_row['conversation_직업정보탐색'] += ' ' + df.iloc[i + 1]['conversation_직업정보탐색']
    combined_rows.append(combined_row)

# 새로운 DataFrame 생성
data_element = pd.DataFrame(combined_rows)

# NaN 처리
data_element.replace(' ', np.nan, inplace=True)
data_element.reset_index(drop=True, inplace=True)
display(data_element.head())
# Out:
#   student_idx                                  conversation_자아이해  \
# 0      S-0155   학생은 형제자매가 어떻게 돼요? 여동생 한 명이에요! 동생이 몇 살인가요? 9살이...
# 1      S-0157   6학년 1학기 학교생활은 어땠나요? 힘들었습니다 왜 힘들었나요? 공부가 어려웠습니...
# 2      S-0170   현재 진로에 대해서 어떤 생각을 하고 있나요? 확실하지는 않지만, 로봇을 연구하는...
# 3      S-0188   그러면 우선 내가 좋아하는 것이 무엇인지 한번 얘기해 볼까요? 편안하게 대화하시면...
# 4      S-0219   여름 방학은 어떻게 보내고 있나요? 학원 가거나 집에서 게임을 하면서 보내고 있어...
#
#                                  conversation_교육기회탐색  \
# 0    학생은 5학년이지만 중학생 정도의 지력을 갖춘 거 같아요 선행학습을 하고 있나요...
# 1                                                NaN
# 2   혹시 직업 선호도 검사나 진로 검사 등 심리 검사를 받아본 적이 있나요? 받아본 ...
# 3   혹시 학생은 대학 진학 혹은 취업 어떤 쪽으로 가까운 미래의 진로를 생각하고 있는...
# 4   주변에 진로를 탐색해볼 만한 곳이 있을까요? 잘 모르겠어요 혹시 꿈의 학교에 대해...
#
#                                  conversation_직업정보탐색  \
# 0   잡월드에서 직업체험을 해봤다고 했는데 어떤 걸 해봤어요? 수의사, 항공사, 경찰,...
# 1                                                NaN
# 2                                                NaN
# 3   이번 방학에 주로 어떤 계획이 있나요? 집에서 운동하는 거 말고는 없어요 그럼 선...
# 4   소프트웨어 개발자에 대해서는 어떻게 생각하게 되었나요? 저희 아빠가 소프트웨어 개...
#
#                                    conversation_직업이해
# 0                                                NaN
# 1  알쏭달쏭 카드는 미래직업 트렌드 카드에요 네 미래직업 트렌드에 대해 알고 있는 것이...
# 2  요즘은 취미를 직업으로 연결하는 사례들이 많죠 그러게요 의사이면서 유튜버고 동시에 ...
# 3  https://m.blog.naver.com/ca7735/222628595278 이...
# 4  과거와 다르게 한 사람이 한 가지 직업을 갖고 사는 게 아니라 이제는 4~9가지의 ...

# %%
print(data_element.isnull().sum())
print(data_element.shape)
# Out:
# student_idx              0
# conversation_자아이해       21
# conversation_교육기회탐색    160
# conversation_직업정보탐색     91
# conversation_직업이해      425
# dtype: int64
# (1188, 5)

# %%
temp_element = data_element.dropna(axis = 0)
print(temp_element.isnull().sum())
print(temp_element.shape)
# Out:
# student_idx            0
# conversation_자아이해      0
# conversation_교육기회탐색    0
# conversation_직업정보탐색    0
# conversation_직업이해      0
# dtype: int64
# (658, 5)
